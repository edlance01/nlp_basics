# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Sample Dataset (Reviews and Labels)
data = {
    "review": [
        "This movie was absolutely wonderful and the acting was superb.",  # Positive
        "A truly terrible and boring plot, a complete waste of time.",  # Negative
        "I enjoyed every moment; a masterpiece of cinema.",  # Positive
        "The story was confusing and the characters were unlikable.",  # Negative
        "Highly recommended! Best film of the year, definitely amazing.",  # Positive
        "Not worth the ticket price; the ending was very disappointing.",  # Negative
        "It was decent, not great but not bad either.",  # Neutral/Ambiguous (will be treated as negative in binary setup)
    ],
    "sentiment": [1, 0, 1, 0, 1, 0, 0],
}

df = pd.DataFrame(data)
df.head()
# Out:
#                                               review  sentiment
# 0  This movie was absolutely wonderful and the ac...          1
# 1  A truly terrible and boring plot, a complete w...          0
# 2   I enjoyed every moment; a masterpiece of cinema.          1
# 3  The story was confusing and the characters wer...          0
# 4  Highly recommended! Best film of the year, def...          1

# %% [markdown]
# Step 1: Load and Prepare the Dataset
# This step loads the text (reviews) and numericalizes the labels (converting 'positive' to 1 and 'negative' to 0).

# %%
import os

# Set your DYLD_LIBRARY_PATH and LD_LIBRARY_PATH variables here
os.environ["DYLD_LIBRARY_PATH"] = (
    "/Users/edwardlance/python_projects/nlp/nlp_basics/venv/lib/python3.13/site-packages/clidriver/lib"
)
os.environ["LD_LIBRARY_PATH"] = (
    "/Users/edwardlance/python_projects/nlp/nlp_basics/venv/lib/python3.13/site-packages/clidriver/lib"
)

# Optional: Print to confirm they were set correctly
print(f"DYLD_LIBRARY_PATH set to: {os.environ.get('DYLD_LIBRARY_PATH')}")
print("-" * 20)

# NOW try your ibm_db import and connection code in this cell or the next one
import ibm_db

# ... rest of your code
# Out:
# DYLD_LIBRARY_PATH set to: /Users/edwardlance/python_projects/nlp/nlp_basics/venv/lib/python3.13/site-packages/clidriver/lib
# --------------------

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the IMDB dataset (note file path)
try:
    df_imdb = pd.read_csv("/data/IMDB Dataset.csv")
    print("finished loading")
except FileNotFoundError:
    print("Error IMDB.cs not found")
    exit()

# show first 5 rows to confirm file loaded
#df_imdb.head()
# Out:
# Error IMDB.cs not found
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
